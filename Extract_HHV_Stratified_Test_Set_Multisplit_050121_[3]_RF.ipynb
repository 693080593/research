# %% [markdown]
# <a href="https://colab.research.google.com/github/693080593/research/blob/master/Extract_HHV_Stratified_Test_Set_Multisplit_050121_%5B3%5D_RF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import libraries necessary for this project
import numpy as np
import pandas as pd

# Import supplementary visualizations code visuals.py
import visuals as vs

# Pretty display for notebooks
# %matplotlib inline

# Load the dataset
data = pd.read_csv(r'/content/Extrantant Type Effect on Biocrude Yield HHV ER 050121 Stratified Test MaxMinScale HHV.csv')
Original_Oil_HHV = data['Bio-crude Oil HHV']
Original_Features = data.drop(['Bio-crude Oil Yield','Bio-crude Oil HHV','Bio-crude Oil ER'], axis = 1)

data_figure = data.drop(['Bio-crude Oil Yield','Bio-crude Oil ER','Group'], axis = 1)

# Success
print ("Bio-crude dataset has {} data points with {} variables each.".format(*data_figure.shape))
data_figure.shape

data_figure[:517:11]
# Out:
# Bio-crude dataset has 316 data points with 17 variables each.
#      Dichloromethane  Toluene  Acetone  ...     Lignin        Ash  Bio-crude Oil HHV
# 0                100        0        0  ...   0.000000   0.000000          74.644424
# 11               100        0        0  ...   0.000000   6.521739          94.274547
# 22                 0        0      100  ...   0.000000   2.100000          67.978361
# 33               100        0        0  ...   0.000000   7.000000          68.918971
# 44               100        0        0  ...   0.000000   6.000000          72.599619
# 55                 0        0        0  ...   0.000000   8.700000          65.647284
# 66                 0        0      100  ...   0.000000   3.470000          59.103909
# 77               100        0        0  ...   0.000000   7.500000          74.644424
# 88               100        0        0  ...   0.000000  16.500000          74.317255
# 99               100        0        0  ...   0.000000  11.080000          83.968732
# 110                0        0        0  ...   0.000000  23.190000          77.302670
# 121              100        0        0  ...   0.000000   6.100000          65.238323
# 132              100        0        0  ...   0.000000   5.800000          65.238323
# 143              100        0        0  ...   0.000000   6.100000          58.694948
# 154              100        0        0  ...   0.000000   8.910000          84.009629
# 165              100        0        0  ...   0.000000   7.600000          77.916111
# 176                0      100        0  ...   5.700000  47.500000          32.930411
# 187              100        0        0  ...  23.200000   0.100000          26.795998
# 198                0        0        0  ...   0.000000  40.630000          71.781697
# 209                0      100        0  ...   4.650000  31.900000          17.525099
# 220              100        0        0  ...   0.000000   0.000000          66.710582
# 231                0        0      100  ...  27.700000   1.100000          92.638704
# 242              100        0        0  ...   0.000000   0.000000          65.647284
# 253                0        0      100  ...   0.700000   0.500000          12.891327
# 264              100        0        0  ...   0.000000   2.520000          52.437847
# 275              100        0        0  ...   0.000000  44.705882          70.145854
# 286              100        0        0  ...  34.570000   4.780000          50.311250
# 297              100        0        0  ...   0.000000  49.570000          78.611345
# 308              100        0        0  ...  22.867338   0.620000          41.804863
#
# [29 rows x 17 columns]

# %%
# MinMaxScale
#from sklearn.preprocessing import MinMaxScaler
#from pandas import DataFrame

#data_MinMax = data2.drop(['Lipid','Protein','Cellulose','Hemicellulose','Carbohydrate','Lignin','Ash','Bio-crude Oil Yield','Group'], axis = 1)

#scaler = MinMaxScaler()

#print(scaler.fit(data_MinMax))

#print(scaler.data_max_)
#print(scaler.data_min_)

#data_MinMax3 = scaler.transform(data_MinMax)

#data_MinMax2 = pd.DataFrame(data = data_MinMax3*100,  columns =["Temperature"])

#print(data_MinMax2)

#Original_Features = pd.concat([data2['Lipid'],data2['Protein'],data2['Cellulose'],data2['Hemicellulose'],data2['Carbohydrate'],data2['Lignin'],data2['Ash'],data_MinMax2, data2['Group']], axis=1)

#data=pd.concat([Original_Features, data2['Bio-crude Oil Yield']], axis=1)

#data_figure_new=data.drop('Group', axis = 1)

#data[:517:11]

#Original_Features[:511:11]

# %%
# Load matplotlib
import matplotlib.pyplot as plt

# Show the figure with higher resolution
# %config InlineBackend.figure_format = 'retina'

# Adjust the size of figure
plt.figure(figsize=(14,14))

plt.subplot(331)
plt.xlabel('Lipid')
plt.ylabel('Bio-crude Oil Yields (wt%)')
plt.scatter(data['Lipid'],data['Bio-crude Oil Yield'],alpha = 0.5)

plt.subplot(332)
plt.xlabel('Protein')
plt.ylabel('Bio-crude Oil Yields (wt%)')
plt.scatter(data['Protein'],data['Bio-crude Oil Yield'],alpha = 0.5)

plt.subplot(333)
plt.xlabel('Cellulose')
plt.ylabel('Bio-crude Oil Yields (wt%)')
plt.scatter(data['Cellulose'],data['Bio-crude Oil Yield'],alpha = 0.5)

plt.subplot(334)
plt.xlabel('Hemicellulose')
plt.ylabel('Bio-crude Oil Yields (wt%)')
plt.scatter(data['Hemicellulose'],data['Bio-crude Oil Yield'],alpha = 0.5)

plt.subplot(335)
plt.xlabel('Carbohydrate')
plt.ylabel('Bio-crude Oil Yields (wt%)')
plt.scatter(data['Carbohydrate'],data['Bio-crude Oil Yield'],alpha = 0.5)

plt.subplot(336)
plt.xlabel('Lignin')
plt.ylabel('Bio-crude Oil Yields (wt%)')
plt.scatter(data['Lignin'],data['Bio-crude Oil Yield'],alpha = 0.5)

plt.subplot(337)
plt.xlabel('Ash')
plt.ylabel('Bio-crude Oil Yields (wt%)')
plt.scatter(data['Ash'],data['Bio-crude Oil Yield'],alpha = 0.5)
plt.show()

plt.subplot(338)
plt.xlabel('Gas Yield')
plt.ylabel('Bio-crude Oil Yields (wt%)')
plt.scatter(data['Gas Yield'],data['Bio-crude Oil Yield'],alpha = 0.5)
plt.show()

# %%
# Correlation
import seaborn as sns
fig=plt.figure(figsize=(16,16))
sns.heatmap(data_figure.corr(),vmax=1,square=True,annot=True)
plt.show()

# %%
import numpy as np
# The mean relative error (MRE) is commonly used to measure the predictive accuracy of models.

def performance_metric(y_true, y_predict):
  """Calculates and returns the performance score between 
        true and predicted values based on the metric chosen."""
  # TODO: Calculate the performance score between 'y_true' and 'y_predict'

  return np.mean(np.abs(y_true-y_predict))/np.mean(y_true)

# %%
# No use.
for i in range(0,201,1):
  # TODO: Import 'RandomForestRegressor'
  from sklearn.ensemble import RandomForestRegressor
  
  # TODO: Import 'Stratified KFold'
  from sklearn.model_selection import StratifiedKFold
  from sklearn.model_selection import train_test_split
  
  # TODO Calculate the r2 score between 'y_true' and 'y_predict'
  from math import sqrt
  from sklearn import metrics
  
  group2 = Original_Features.loc[:,'Group']

  # TODO: Shuffle and split the data into training and testing subsets
  Features, X_valid, Oil_Yields, y_valid = train_test_split(Original_Features, Original_Oil_Yields, test_size = 0.1, stratify=group2, random_state=i)
  
  X_valid_new=X_valid.drop('Group', axis=1)
  
  df = pd.concat([Features, Oil_Yields], axis=1)
  
  # Lets split the data into 10 folds. 
  skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=26)
  
  group = df.loc[:,'Group']
  
  cnt = 1
  
  r2_train_all=[]
  r2_test_all=[]
  MRE_train_all=[]
  MRE_test_all=[]
  
  # split()  method generate indices to split data into training and test set.
  
  for train_index, test_index in skf.split(df, group):
    
    train = df.iloc[train_index,:]
    test = df.iloc[test_index,:]
    
    X_train=train.drop(['Bio-crude Oil Yield','Group'], axis=1)
    y_train=train['Bio-crude Oil Yield']
    
    X_test=test.drop(['Bio-crude Oil Yield','Group'], axis=1)
    y_test=test['Bio-crude Oil Yield']

    model = RandomForestRegressor()

    model.fit(X_train, y_train)
    
    y_train_predict = model.predict(X_train)
    y_test_predict = model.predict(X_test)
    
    r2_train = metrics.r2_score(y_train, y_train_predict)
    r2_test = metrics.r2_score(y_test, y_test_predict)
    
    MRE_train = performance_metric(y_train, y_train_predict)
    MRE_test = performance_metric(y_test, y_test_predict)

    cnt += 1
    
    r2_train_all.append(r2_train)
    r2_test_all.append(r2_test) 
    MRE_train_all.append(MRE_train)
    MRE_test_all.append(MRE_test)
    
  # Predict validation set
  y_valid_predict = model.predict(X_valid_new)
  
  r2_valid = metrics.r2_score(y_valid, y_valid_predict)

  MRE_valid = performance_metric(y_valid, y_valid_predict)

  print(i)
  print("Mean value of R2 of training set", np.mean(r2_train_all))
  print("Mean value of R2 of test set", np.mean(r2_test_all))
  print("Difference Values of R2 of training and test sets", np.mean(r2_train_all)-np.mean(r2_test_all))
  print("Values of R2 of test set", r2_test_all)
  print("Difference Values of R2 Max and Min of test set", max(r2_test_all)-min(r2_test_all))
  print("Optimal model has R2 score of valid set", r2_valid)
  print("")
  #print("Mean value of MRE of training set", np.mean(MRE_train_all))
  #print("Mean value of MRE of test set", np.mean(MRE_test_all))
  #print("Difference Values of MRE of training and test sets", np.mean(MRE_train_all)-np.mean(MRE_test_all))
  #print("Values of MRE of test set", MRE_test_all)
  #print("Difference Values of MRE Max and Min of test set", max(MRE_test_all)-min(MRE_test_all))
  #print("Optimal model has MRE of valid set:", MRE_valid)

# %%
# TODO: Import 'RandomForestRegressor'
from sklearn.ensemble import RandomForestRegressor

from sklearn.model_selection import train_test_split

# TODO Calculate the r2 score between 'y_true' and 'y_predict'
from math import sqrt
from sklearn import metrics

group2 = Original_Features.loc[:,'Group']

# TODO: Shuffle and split the data into training and testing subsets
Features, X_valid, Oil_HHV, y_valid = train_test_split(Original_Features, Original_Oil_HHV, test_size = 0.1, stratify=group2, random_state=62)

X_valid_new=X_valid.drop('Group', axis=1)

Features_new=Features.drop('Group', axis=1)

cnt = 1

MAE_train_all=[]
MAE_test_all=[]
y_train_rmse_all=[]
y_test_rmse_all=[]
r2_train_all=[]
r2_test_all=[]
MRE_train_all=[]
MRE_test_all=[]
y_test_list=[]
y_pred_list=[]

# split()  method generate indices to split data into training and test set.
for i in range(5000,6000,10):

  X_train, X_test, y_train, y_test = train_test_split(Features_new, Oil_HHV, shuffle=True, test_size = 0.2, random_state=i)
    
  model = RandomForestRegressor(random_state=33)
  model.fit(X_train, y_train)
    
  y_train_predict = model.predict(X_train)
  y_test_predict = model.predict(X_test)

  MAE_train = metrics.mean_absolute_error(y_train, y_train_predict)
  MAE_test = metrics.mean_absolute_error(y_test, y_test_predict)
    
  y_train_rmse = sqrt(metrics.mean_squared_error(y_train, y_train_predict))
  y_test_rmse = sqrt(metrics.mean_squared_error(y_test, y_test_predict))
    
  r2_train = metrics.r2_score(y_train, y_train_predict)
  r2_test = metrics.r2_score(y_test, y_test_predict)

  MRE_train = performance_metric(y_train, y_train_predict)
  MRE_test = performance_metric(y_test, y_test_predict)

  cnt += 1
  MAE_train_all.append(MAE_train)
  MAE_test_all.append(MAE_test)
  y_train_rmse_all.append(y_train_rmse)
  y_test_rmse_all.append(y_test_rmse)
  r2_train_all.append(r2_train)
  r2_test_all.append(r2_test)
  MRE_train_all.append(MRE_train)
  MRE_test_all.append(MRE_test)
  y_test_list.append(y_test.values)
  y_pred_list.append(y_test_predict)

y_test_all=np.concatenate(y_test_list, axis=0)
y_pred_all=np.concatenate(y_pred_list, axis=0)

print("Mean value of MAE of training set", np.mean(MAE_train_all))
print("Standard deviation of MAE of training set", np.std(MAE_train_all))
print("Mean value of MAE of test set", np.mean(MAE_test_all))
print("Standard deviation of MAE of test set", np.std(MAE_test_all))
print("")
print("Mean value of RMSE of training set", np.mean(y_train_rmse_all))
print("Standard deviation of RMSE of training set", np.std(y_train_rmse_all))
print("Mean value of RMSE of test set", np.mean(y_test_rmse_all))
print("Standard deviation of RMSE of test set", np.std(y_test_rmse_all))
print("")
print("Mean value of R2 of training set", np.mean(r2_train_all))
print("Standard deviation of R2 of training set", np.std(r2_train_all))
print("Mean value of R2 of test set", np.mean(r2_test_all))
print("Standard deviation of R2 of test set", np.std(r2_test_all))
print("")
print("Mean value of MRE of training set", np.mean(MRE_train_all))
print("Standard deviation of MRE of training set", np.std(MRE_train_all))
print("Mean value of MRE of test set", np.mean(MRE_test_all))
print("Standard deviation of MRE of test set", np.std(MRE_test_all))

# print(len(np.concatenate(y_test_list, axis=0)))
# print(len(np.concatenate(y_pred_list, axis=0)))

print("")
# Predict validation set
model.fit(Features_new, Oil_HHV)

y_valid_predict = model.predict(X_valid_new)

MAE_valid = metrics.mean_absolute_error(y_valid, y_valid_predict)
y_valid_rmse = sqrt(metrics.mean_squared_error(y_valid, y_valid_predict))
r2_valid = metrics.r2_score(y_valid, y_valid_predict)
MRE_valid = performance_metric(y_valid, y_valid_predict)

print("Optimal model has MAE of valid set:", MAE_valid)
print("Optimal model has RMSE of valid set:", y_valid_rmse)
print("Optimal model has R2 score of valid set", r2_valid)
print("Optimal model has MRE of valid set:", MRE_valid)

# %%
import matplotlib.pyplot as py
py.plot(y_test_all, y_pred_all, 'bo')
py.ylim(0, 50)
py.xlabel('y_true')
py.ylabel('y_pred')
py.title('y_pred vs. y_true')
# Out:
# Text(0.5, 1.0, 'y_pred vs. y_true')

# %%
Parity={'Predict Data':y_pred_all,'Test Data':y_test_all}
df = pd.DataFrame(Parity, columns= ['Predict Data', 'Test Data'])
df.to_csv (r'/content/export_dataframe_RFR.csv', index = False, header=True)

# %%
import matplotlib.pyplot as py
py.plot(y_valid, y_valid_predict, 'bo')
py.ylim(20, 50)
py.xlabel('y_true')
py.ylabel('y_pred')
py.title('y_pred vs. y_true')
# Out:
# Text(0.5, 1.0, 'y_pred vs. y_true')

# %%
# n_estimators 参数的最佳取值(10, 200, 11)

for j in range(10, 200, 10):

  # TODO: Import 'RandomForestRegressor'
  from sklearn.ensemble import RandomForestRegressor

  from sklearn.model_selection import train_test_split
  
  # TODO Calculate the r2 score between 'y_true' and 'y_predict'
  from math import sqrt
  from sklearn import metrics
  
  group2 = Original_Features.loc[:,'Group']

  # TODO: Shuffle and split the data into training and testing subsets
  Features, X_valid, Oil_HHV, y_valid = train_test_split(Original_Features, Original_Oil_HHV, test_size = 0.1, stratify=group2, random_state=62)
  
  X_valid_new=X_valid.drop('Group', axis=1)
  
  Features_new=Features.drop('Group', axis=1)
  
  cnt = 1
  
  r2_train_all=[]
  r2_test_all=[]
  
  # split()  method generate indices to split data into training and test set.
  
  for i in range(5000,6000,10):
    
    X_train, X_test, y_train, y_test = train_test_split(Features_new, Oil_HHV, shuffle=True, test_size = 0.2, random_state=i)

    params = {'n_estimators':j,'max_depth':13,'min_samples_leaf':1,'min_samples_split':2,'max_features':6,'random_state':33}

    model = RandomForestRegressor(**params)

    model.fit(X_train, y_train)
    
    y_train_predict = model.predict(X_train)
    y_test_predict = model.predict(X_test)
    
    r2_train = metrics.r2_score(y_train, y_train_predict)
    r2_test = metrics.r2_score(y_test, y_test_predict)
    
    cnt += 1
    
    r2_train_all.append(r2_train)
    r2_test_all.append(r2_test) 
    
  # Predict validation set
  #model.fit(Features_new, Oil_HHV)
  #y_valid_predict = model.predict(X_valid_new)
  
  #r2_valid = metrics.r2_score(y_valid, y_valid_predict)

  print(j)
  print("Mean value of R2 of training set", np.mean(r2_train_all))
  print("Mean value of R2 of test set", np.mean(r2_test_all))
  #print("R2 score of valid set", r2_valid)
  #print("Max value of R2 of test set", max(r2_test_all))
  print("Standard deviation of R2 of test set", np.std(r2_test_all))
  print("Train-Test:",np.mean(r2_train_all)-np.mean(r2_test_all))
  #print("Testmax-Valid:",max(r2_test_all)-r2_valid)

# %%
# max_depth 参数的最佳取值(1, 20, 1)

for j in range(1, 20, 1):

  # TODO: Import 'RandomForestRegressor'
  from sklearn.ensemble import RandomForestRegressor

  from sklearn.model_selection import train_test_split
  
  # TODO Calculate the r2 score between 'y_true' and 'y_predict'
  from math import sqrt
  from sklearn import metrics
  
  group2 = Original_Features.loc[:,'Group']

  # TODO: Shuffle and split the data into training and testing subsets
  Features, X_valid, Oil_HHV, y_valid = train_test_split(Original_Features, Original_Oil_HHV, test_size = 0.1, stratify=group2, random_state=62)
  
  X_valid_new=X_valid.drop('Group', axis=1)
  
  Features_new=Features.drop('Group', axis=1)
  
  cnt = 1
  
  r2_train_all=[]
  r2_test_all=[]
  
  # split()  method generate indices to split data into training and test set.
  
  for i in range(5000,6000,10):
    
    X_train, X_test, y_train, y_test = train_test_split(Features_new, Oil_HHV, shuffle=True, test_size = 0.2, random_state=i)

    params = {'n_estimators':190,'max_depth':j,'min_samples_leaf':1,'min_samples_split':2,'max_features':6,'random_state':33}

    model = RandomForestRegressor(**params)

    model.fit(X_train, y_train)
    
    y_train_predict = model.predict(X_train)
    y_test_predict = model.predict(X_test)
    
    r2_train = metrics.r2_score(y_train, y_train_predict)
    r2_test = metrics.r2_score(y_test, y_test_predict)
    
    cnt += 1
    
    r2_train_all.append(r2_train)
    r2_test_all.append(r2_test) 
    
  # Predict validation set
  #model.fit(Features_new, Oil_HHV)
  #y_valid_predict = model.predict(X_valid_new)
  
  #r2_valid = metrics.r2_score(y_valid, y_valid_predict)

  print(j)
  print("Mean value of R2 of training set", np.mean(r2_train_all))
  print("Mean value of R2 of test set", np.mean(r2_test_all))
  #print("R2 score of valid set", r2_valid)
  #print("Max value of R2 of test set", max(r2_test_all))
  print("Standard deviation of R2 of test set", np.std(r2_test_all))
  print("Train-Test:",np.mean(r2_train_all)-np.mean(r2_test_all))
  #print("Testmax-Valid:",max(r2_test_all)-r2_valid)

# %%
# min_samples_leaf 参数的最佳取值(1, 3, 1)

for j in range(1, 3, 1):

  # TODO: Import 'RandomForestRegressor'
  from sklearn.ensemble import RandomForestRegressor

  from sklearn.model_selection import train_test_split
  
  # TODO Calculate the r2 score between 'y_true' and 'y_predict'
  from math import sqrt
  from sklearn import metrics
  
  group2 = Original_Features.loc[:,'Group']

  # TODO: Shuffle and split the data into training and testing subsets
  Features, X_valid, Oil_HHV, y_valid = train_test_split(Original_Features, Original_Oil_HHV, test_size = 0.1, stratify=group2, random_state=62)
  
  X_valid_new=X_valid.drop('Group', axis=1)
  
  Features_new=Features.drop('Group', axis=1)
  
  cnt = 1
  
  r2_train_all=[]
  r2_test_all=[]
  
  # split()  method generate indices to split data into training and test set.
  
  for i in range(5000,6000,10):
    
    X_train, X_test, y_train, y_test = train_test_split(Features_new, Oil_HHV, shuffle=True, test_size = 0.2, random_state=i)

    params = {'n_estimators':190,'max_depth':12,'min_samples_leaf':j,'min_samples_split':2,'max_features':6,'random_state':33}

    model = RandomForestRegressor(**params)

    model.fit(X_train, y_train)
    
    y_train_predict = model.predict(X_train)
    y_test_predict = model.predict(X_test)
    
    r2_train = metrics.r2_score(y_train, y_train_predict)
    r2_test = metrics.r2_score(y_test, y_test_predict)
    
    cnt += 1
    
    r2_train_all.append(r2_train)
    r2_test_all.append(r2_test) 
    
  # Predict validation set
  #model.fit(Features_new, Oil_HHV)
  #y_valid_predict = model.predict(X_valid_new)
  
  #r2_valid = metrics.r2_score(y_valid, y_valid_predict)

  print(j)
  print("Mean value of R2 of training set", np.mean(r2_train_all))
  print("Mean value of R2 of test set", np.mean(r2_test_all))
  #print("R2 score of valid set", r2_valid)
  #print("Max value of R2 of test set", max(r2_test_all))
  print("Standard deviation of R2 of test set", np.std(r2_test_all))
  print("Train-Test:",np.mean(r2_train_all)-np.mean(r2_test_all))
  #print("Testmax-Valid:",max(r2_test_all)-r2_valid)

# %%
# min_samples_split 参数的最佳取值(2, 5, 20)

for j in range(2, 5, 1):

  # TODO: Import 'RandomForestRegressor'
  from sklearn.ensemble import RandomForestRegressor

  from sklearn.model_selection import train_test_split
  
  # TODO Calculate the r2 score between 'y_true' and 'y_predict'
  from math import sqrt
  from sklearn import metrics
  
  group2 = Original_Features.loc[:,'Group']

  # TODO: Shuffle and split the data into training and testing subsets
  Features, X_valid, Oil_HHV, y_valid = train_test_split(Original_Features, Original_Oil_HHV, test_size = 0.1, stratify=group2, random_state=62)
  
  X_valid_new=X_valid.drop('Group', axis=1)
  
  Features_new=Features.drop('Group', axis=1)
  
  cnt = 1
  
  r2_train_all=[]
  r2_test_all=[]
  
  # split()  method generate indices to split data into training and test set.
  
  for i in range(5000,6000,10):
    
    X_train, X_test, y_train, y_test = train_test_split(Features_new, Oil_HHV, shuffle=True, test_size = 0.2, random_state=i)

    params = {'n_estimators':190,'max_depth':12,'min_samples_leaf':1,'min_samples_split':j,'max_features':6,'random_state':33}

    model = RandomForestRegressor(**params)

    model.fit(X_train, y_train)
    
    y_train_predict = model.predict(X_train)
    y_test_predict = model.predict(X_test)
    
    r2_train = metrics.r2_score(y_train, y_train_predict)
    r2_test = metrics.r2_score(y_test, y_test_predict)
    
    cnt += 1
    
    r2_train_all.append(r2_train)
    r2_test_all.append(r2_test) 
    
  # Predict validation set
  #model.fit(Features_new, Oil_HHV)
  #y_valid_predict = model.predict(X_valid_new)
  
  #r2_valid = metrics.r2_score(y_valid, y_valid_predict)

  print(j)
  print("Mean value of R2 of training set", np.mean(r2_train_all))
  print("Mean value of R2 of test set", np.mean(r2_test_all))
  #print("R2 score of valid set", r2_valid)
  #print("Max value of R2 of test set", max(r2_test_all))
  print("Standard deviation of R2 of test set", np.std(r2_test_all))
  print("Train-Test:",np.mean(r2_train_all)-np.mean(r2_test_all))
  #print("Testmax-Valid:",max(r2_test_all)-r2_valid)

# %%
# max_features 参数的最佳取值(1, 8, 1)

for j in range(1, 8, 1):

  # TODO: Import 'RandomForestRegressor'
  from sklearn.ensemble import RandomForestRegressor

  from sklearn.model_selection import train_test_split
  
  # TODO Calculate the r2 score between 'y_true' and 'y_predict'
  from math import sqrt
  from sklearn import metrics
  
  group2 = Original_Features.loc[:,'Group']

  # TODO: Shuffle and split the data into training and testing subsets
  Features, X_valid, Oil_HHV, y_valid = train_test_split(Original_Features, Original_Oil_HHV, test_size = 0.1, stratify=group2, random_state=62)
  
  X_valid_new=X_valid.drop('Group', axis=1)
  
  Features_new=Features.drop('Group', axis=1)
  
  cnt = 1
  
  r2_train_all=[]
  r2_test_all=[]
  
  # split()  method generate indices to split data into training and test set.
  
  for i in range(5000,6000,10):
    
    X_train, X_test, y_train, y_test = train_test_split(Features_new, Oil_HHV, shuffle=True, test_size = 0.2, random_state=i)

    params = {'n_estimators':190,'max_depth':12,'min_samples_leaf':1,'min_samples_split':4,'max_features':j,'random_state':33}

    model = RandomForestRegressor(**params)

    model.fit(X_train, y_train)
    
    y_train_predict = model.predict(X_train)
    y_test_predict = model.predict(X_test)
    
    r2_train = metrics.r2_score(y_train, y_train_predict)
    r2_test = metrics.r2_score(y_test, y_test_predict)
    
    cnt += 1
    
    r2_train_all.append(r2_train)
    r2_test_all.append(r2_test) 
    
  # Predict validation set
  #model.fit(Features_new, Oil_HHV)
  #y_valid_predict = model.predict(X_valid_new)
  
  #r2_valid = metrics.r2_score(y_valid, y_valid_predict)

  print(j)
  print("Mean value of R2 of training set", np.mean(r2_train_all))
  print("Mean value of R2 of test set", np.mean(r2_test_all))
  #print("R2 score of valid set", r2_valid)
  #print("Max value of R2 of test set", max(r2_test_all))
  print("Standard deviation of R2 of test set", np.std(r2_test_all))
  print("Train-Test:",np.mean(r2_train_all)-np.mean(r2_test_all))
  #print("Testmax-Valid:",max(r2_test_all)-r2_valid)

# %%
# random_state 参数的最佳取值(1, 201, 1)

for j in range(1, 201, 1):

  # TODO: Import 'RandomForestRegressor'
  from sklearn.ensemble import RandomForestRegressor

  from sklearn.model_selection import train_test_split
  
  # TODO Calculate the r2 score between 'y_true' and 'y_predict'
  from math import sqrt
  from sklearn import metrics
  
  group2 = Original_Features.loc[:,'Group']

  # TODO: Shuffle and split the data into training and testing subsets
  Features, X_valid, Oil_HHV, y_valid = train_test_split(Original_Features, Original_Oil_HHV, test_size = 0.1, stratify=group2, random_state=62)
  
  X_valid_new=X_valid.drop('Group', axis=1)
  
  Features_new=Features.drop('Group', axis=1)
  
  cnt = 1
  
  r2_train_all=[]
  r2_test_all=[]
  
  # split()  method generate indices to split data into training and test set.
  
  for i in range(5000,6000,10):
    
    X_train, X_test, y_train, y_test = train_test_split(Features_new, Oil_HHV, shuffle=True, test_size = 0.2, random_state=i)

    params = {'n_estimators':190,'max_depth':12,'min_samples_leaf':1,'min_samples_split':4,'max_features':1,'random_state':j}

    model = RandomForestRegressor(**params)

    model.fit(X_train, y_train)
    
    y_train_predict = model.predict(X_train)
    y_test_predict = model.predict(X_test)
    
    r2_train = metrics.r2_score(y_train, y_train_predict)
    r2_test = metrics.r2_score(y_test, y_test_predict)
    
    cnt += 1
    
    r2_train_all.append(r2_train)
    r2_test_all.append(r2_test) 
    
  # Predict validation set
  #model.fit(Features_new, Oil_HHV)
  #y_valid_predict = model.predict(X_valid_new)
  
  #r2_valid = metrics.r2_score(y_valid, y_valid_predict)

  print(j)
  print("Mean value of R2 of training set", np.mean(r2_train_all))
  print("Mean value of R2 of test set", np.mean(r2_test_all))
  #print("R2 score of valid set", r2_valid)
  #print("Max value of R2 of test set", max(r2_test_all))
  print("Standard deviation of R2 of test set", np.std(r2_test_all))
  print("Train-Test:",np.mean(r2_train_all)-np.mean(r2_test_all))
  #print("Testmax-Valid:",max(r2_test_all)-r2_valid)
# Out:
# 1
# Mean value of R2 of training set 0.7950980197465488
# Mean value of R2 of test set 0.39623657360256814
# Standard deviation of R2 of test set 0.12285089024209217
# Train-Test: 0.39886144614398067
# 2
# Mean value of R2 of training set 0.7952269145376201
# Mean value of R2 of test set 0.4017842409893636
# Standard deviation of R2 of test set 0.12149989792993363
# Train-Test: 0.39344267354825646
# 3
# Mean value of R2 of training set 0.793127417537261
# Mean value of R2 of test set 0.3933797265828254
# Standard deviation of R2 of test set 0.12241098357962504
# Train-Test: 0.39974769095443563
# 4
# Mean value of R2 of training set 0.7966491670733283
# Mean value of R2 of test set 0.3987345720721992
# Standard deviation of R2 of test set 0.11923132355921674
# Train-Test: 0.39791459500112913
# 5
# Mean value of R2 of training set 0.7937603826065298
# Mean value of R2 of test set 0.39575781099855784
# Standard deviation of R2 of test set 0.12177430126452281
# Train-Test: 0.398002571607972
# 6
# Mean value of R2 of training set 0.7936309646213631
# Mean value of R2 of test set 0.39616141324098286
# Standard deviation of R2 of test set 0.1233669864829128
# Train-Test: 0.3974695513803802
# 7
# Mean value of R2 of training set 0.7974296486622149
# Mean value of R2 of test set 0.3959310936096462
# Standard deviation of R2 of test set 0.11735078446869789
# Train-Test: 0.4014985550525687
# 8
# Mean value of R2 of training set 0.7953776351309346
# Mean value of R2 of test set 0.39633044391303346
# Standard deviation of R2 of test set 0.11997705081358437
# Train-Test: 0.39904719121790116
# 9
# Mean value of R2 of training set 0.7950844499347629
# Mean value of R2 of test set 0.3977852918562677
# Standard deviation of R2 of test set 0.12494840576293176
# Train-Test: 0.3972991580784952
# 10
# Mean value of R2 of training set 0.7970170555625968
# Mean value of R2 of test set 0.40002186368768716
# Standard deviation of R2 of test set 0.12106869119245156
# Train-Test: 0.39699519187490967
# 11
# Mean value of R2 of training set 0.7935334689158523
# Mean value of R2 of test set 0.397649239785119
# Standard deviation of R2 of test set 0.12414910223361257
# Train-Test: 0.3958842291307333
# 12
# Mean value of R2 of training set 0.7946196951043681
# Mean value of R2 of test set 0.3934909691074682
# Standard deviation of R2 of test set 0.12183862194080099
# Train-Test: 0.4011287259968999
# 13
# Mean value of R2 of training set 0.7943232429795141
# Mean value of R2 of test set 0.3957195707209689
# Standard deviation of R2 of test set 0.12054995436932457
# Train-Test: 0.39860367225854515
# 14
# Mean value of R2 of training set 0.796445921494822
# Mean value of R2 of test set 0.39796194517966954
# Standard deviation of R2 of test set 0.12057258995642402
# Train-Test: 0.3984839763151524
# 15
# Mean value of R2 of training set 0.7955868959671352
# Mean value of R2 of test set 0.3991407595044782
# Standard deviation of R2 of test set 0.12410808888492092
# Train-Test: 0.396446136462657
# 16
# Mean value of R2 of training set 0.7961356864784939
# Mean value of R2 of test set 0.3971628800354237
# Standard deviation of R2 of test set 0.12184027098798633
# Train-Test: 0.39897280644307015
# 17
# Mean value of R2 of training set 0.7963898541310077
# Mean value of R2 of test set 0.3934537514679012
# Standard deviation of R2 of test set 0.12420294618012484
# Train-Test: 0.40293610266310653
# 18
# Mean value of R2 of training set 0.7944033573942899
# Mean value of R2 of test set 0.395985508718212
# Standard deviation of R2 of test set 0.12507368338980807
# Train-Test: 0.39841784867607793
# 19
# Mean value of R2 of training set 0.7947499093233347
# Mean value of R2 of test set 0.3944791593189393
# Standard deviation of R2 of test set 0.11867259146387547
# Train-Test: 0.4002707500043954
# 20
# Mean value of R2 of training set 0.7964432269584515
# Mean value of R2 of test set 0.3945152024449471
# Standard deviation of R2 of test set 0.12401681530277041
# Train-Test: 0.4019280245135044
# 21
# Mean value of R2 of training set 0.7950354927861899
# Mean value of R2 of test set 0.3960254800814721
# Standard deviation of R2 of test set 0.11931169626261792
# Train-Test: 0.3990100127047178
# 22
# Mean value of R2 of training set 0.7963235712475248
# Mean value of R2 of test set 0.39690112990666426
# Standard deviation of R2 of test set 0.12457145358220621
# Train-Test: 0.3994224413408606
# 23
# Mean value of R2 of training set 0.7963251840133614
# Mean value of R2 of test set 0.3957752388600842
# Standard deviation of R2 of test set 0.12377857911669725
# Train-Test: 0.4005499451532772
# 24
# Mean value of R2 of training set 0.7962086044799846
# Mean value of R2 of test set 0.39602447368305527
# Standard deviation of R2 of test set 0.11940068590573846
# Train-Test: 0.4001841307969294
# 25
# Mean value of R2 of training set 0.7945729582965129
# Mean value of R2 of test set 0.3950072538101294
# Standard deviation of R2 of test set 0.12412909145333137
# Train-Test: 0.39956570448638346
# 26
# Mean value of R2 of training set 0.7945805563964575
# Mean value of R2 of test set 0.3982302507227057
# Standard deviation of R2 of test set 0.11772594197391872
# Train-Test: 0.39635030567375185
# 27
# Mean value of R2 of training set 0.7954649438907104
# Mean value of R2 of test set 0.39583052704706617
# Standard deviation of R2 of test set 0.1240422227902518
# Train-Test: 0.39963441684364426
# 28
# Mean value of R2 of training set 0.7960954663727406
# Mean value of R2 of test set 0.4006881963151849
# Standard deviation of R2 of test set 0.12176072943703874
# Train-Test: 0.39540727005755577
# 29
# Mean value of R2 of training set 0.7958553599897848
# Mean value of R2 of test set 0.3964166998757481
# Standard deviation of R2 of test set 0.1209120820282628
# Train-Test: 0.3994386601140367
# 30
# Mean value of R2 of training set 0.793829678526401
# Mean value of R2 of test set 0.39709597311000594
# Standard deviation of R2 of test set 0.12091680512527177
# Train-Test: 0.396733705416395
# 31
# Mean value of R2 of training set 0.7922969329573369
# Mean value of R2 of test set 0.3928027008828466
# Standard deviation of R2 of test set 0.122795728069974
# Train-Test: 0.39949423207449036
# 32
# Mean value of R2 of training set 0.7944222406406257
# Mean value of R2 of test set 0.39399249709785766
# Standard deviation of R2 of test set 0.12073969034264413
# Train-Test: 0.40042974354276806
# 33
# Mean value of R2 of training set 0.795142646882181
# Mean value of R2 of test set 0.39683850082384303
# Standard deviation of R2 of test set 0.12405402832785274
# Train-Test: 0.3983041460583379
# 34
# Mean value of R2 of training set 0.7966007296610068
# Mean value of R2 of test set 0.3960471453300787
# Standard deviation of R2 of test set 0.12198682152259845
# Train-Test: 0.40055358433092814
# 35
# Mean value of R2 of training set 0.7955709470873841
# Mean value of R2 of test set 0.3994033364619245
# Standard deviation of R2 of test set 0.11964410257253646
# Train-Test: 0.3961676106254596
# 36
# Mean value of R2 of training set 0.795130731230673
# Mean value of R2 of test set 0.3964586168568058
# Standard deviation of R2 of test set 0.12145814155868108
# Train-Test: 0.39867211437386724
# 37
# Mean value of R2 of training set 0.7959761960762767
# Mean value of R2 of test set 0.40153718904696833
# Standard deviation of R2 of test set 0.1187454080622956
# Train-Test: 0.39443900702930834
# 38
# Mean value of R2 of training set 0.7934471162637748
# Mean value of R2 of test set 0.39140654644927075
# Standard deviation of R2 of test set 0.1220207148559383
# Train-Test: 0.4020405698145041
# 39
# Mean value of R2 of training set 0.7958503431123803
# Mean value of R2 of test set 0.4026146471275372
# Standard deviation of R2 of test set 0.1198532467167617
# Train-Test: 0.39323569598484315
# 40
# Mean value of R2 of training set 0.7924233318434659
# Mean value of R2 of test set 0.39692526452328786
# Standard deviation of R2 of test set 0.12202840698474235
# Train-Test: 0.39549806732017806
# 41
# Mean value of R2 of training set 0.7928348857619387
# Mean value of R2 of test set 0.3926613457453342
# Standard deviation of R2 of test set 0.1215488734952624
# Train-Test: 0.40017354001660455
# 42
# Mean value of R2 of training set 0.7947970032190784
# Mean value of R2 of test set 0.39858518422739797
# Standard deviation of R2 of test set 0.12075985444373992
# Train-Test: 0.39621181899168045
# 43
# Mean value of R2 of training set 0.7973763338477897
# Mean value of R2 of test set 0.39724090333397266
# Standard deviation of R2 of test set 0.12195526438097717
# Train-Test: 0.40013543051381706
# 44
# Mean value of R2 of training set 0.7974861692514067
# Mean value of R2 of test set 0.3997100182912851
# Standard deviation of R2 of test set 0.12116969852437566
# Train-Test: 0.3977761509601216
# 45
# Mean value of R2 of training set 0.7940328058417602
# Mean value of R2 of test set 0.39754320189018366
# Standard deviation of R2 of test set 0.12369154810201655
# Train-Test: 0.3964896039515765
# 46
# Mean value of R2 of training set 0.7940204644135559
# Mean value of R2 of test set 0.3954457637993012
# Standard deviation of R2 of test set 0.11684397802240049
# Train-Test: 0.3985747006142547
# 47
# Mean value of R2 of training set 0.7969346602504469
# Mean value of R2 of test set 0.3970492677943823
# Standard deviation of R2 of test set 0.12358409327653636
# Train-Test: 0.3998853924560646
# 48
# Mean value of R2 of training set 0.7957464370184091
# Mean value of R2 of test set 0.3959921478954112
# Standard deviation of R2 of test set 0.11850356590701291
# Train-Test: 0.3997542891229979
# 49
# Mean value of R2 of training set 0.7982764720224398
# Mean value of R2 of test set 0.3963882176877042
# Standard deviation of R2 of test set 0.11957317585091914
# Train-Test: 0.4018882543347356
# 50
# Mean value of R2 of training set 0.7971248633594128
# Mean value of R2 of test set 0.4042531347376984
# Standard deviation of R2 of test set 0.11880208313652163
# Train-Test: 0.3928717286217144
# 51
# Mean value of R2 of training set 0.7957966753733487
# Mean value of R2 of test set 0.40079899163320204
# Standard deviation of R2 of test set 0.12390366979727463
# Train-Test: 0.3949976837401467
# 52
# Mean value of R2 of training set 0.7936066467017625
# Mean value of R2 of test set 0.394923426488076
# Standard deviation of R2 of test set 0.12056979993382855
# Train-Test: 0.3986832202136865
# 53
# Mean value of R2 of training set 0.7954492122144995
# Mean value of R2 of test set 0.39580604117212786
# Standard deviation of R2 of test set 0.12593691493543643
# Train-Test: 0.3996431710423716
# 54
# Mean value of R2 of training set 0.7948493696912393
# Mean value of R2 of test set 0.39818023076466136
# Standard deviation of R2 of test set 0.12331156744870367
# Train-Test: 0.39666913892657796
# 55
# Mean value of R2 of training set 0.7965144061798966
# Mean value of R2 of test set 0.3960776744035116
# Standard deviation of R2 of test set 0.12041083911711412
# Train-Test: 0.40043673177638495
# 56
# Mean value of R2 of training set 0.796361764097907
# Mean value of R2 of test set 0.39665078688560834
# Standard deviation of R2 of test set 0.12041198250764668
# Train-Test: 0.3997109772122987
# 57
# Mean value of R2 of training set 0.796537928457657
# Mean value of R2 of test set 0.39942355287702264
# Standard deviation of R2 of test set 0.12106988706092771
# Train-Test: 0.3971143755806344
# 58
# Mean value of R2 of training set 0.7985975728776499
# Mean value of R2 of test set 0.3996471088517278
# Standard deviation of R2 of test set 0.12187487243268869
# Train-Test: 0.3989504640259221
# 59
# Mean value of R2 of training set 0.7964369204214177
# Mean value of R2 of test set 0.3970294284546707
# Standard deviation of R2 of test set 0.12193580393086274
# Train-Test: 0.39940749196674696
# 60
# Mean value of R2 of training set 0.7931712381809044
# Mean value of R2 of test set 0.39780709354187294
# Standard deviation of R2 of test set 0.1213731182767607
# Train-Test: 0.39536414463903147
# 61
# Mean value of R2 of training set 0.7954314743260156
# Mean value of R2 of test set 0.39888329171375436
# Standard deviation of R2 of test set 0.12155596126117703
# Train-Test: 0.3965481826122612
# 62
# Mean value of R2 of training set 0.7948990796342015
# Mean value of R2 of test set 0.39930327645887076
# Standard deviation of R2 of test set 0.12205052098817025
# Train-Test: 0.3955958031753307
# 63
# Mean value of R2 of training set 0.7958911467496415
# Mean value of R2 of test set 0.3979838313724125
# Standard deviation of R2 of test set 0.1220952583793599
# Train-Test: 0.39790731537722895
# 64
# Mean value of R2 of training set 0.7942060558753157
# Mean value of R2 of test set 0.3967184892594554
# Standard deviation of R2 of test set 0.12284891010008114
# Train-Test: 0.39748756661586027
# 65
# Mean value of R2 of training set 0.7972812176026071
# Mean value of R2 of test set 0.3990018505284196
# Standard deviation of R2 of test set 0.11963959520001985
# Train-Test: 0.3982793670741875
# 66
# Mean value of R2 of training set 0.7937969281120273
# Mean value of R2 of test set 0.39574579967207973
# Standard deviation of R2 of test set 0.1228427398768314
# Train-Test: 0.39805112843994755
# 67
# Mean value of R2 of training set 0.7974274480504715
# Mean value of R2 of test set 0.396911719040142
# Standard deviation of R2 of test set 0.12168218273645716
# Train-Test: 0.4005157290103295
# 68
# Mean value of R2 of training set 0.797358736873756
# Mean value of R2 of test set 0.395911334284729
# Standard deviation of R2 of test set 0.12168295736175876
# Train-Test: 0.401447402589027
# 69
# Mean value of R2 of training set 0.7941586750522659
# Mean value of R2 of test set 0.39712633024967015
# Standard deviation of R2 of test set 0.12595152088714706
# Train-Test: 0.39703234480259575
# 70
# Mean value of R2 of training set 0.7953262398249008
# Mean value of R2 of test set 0.40091934549476027
# Standard deviation of R2 of test set 0.11955461660484994
# Train-Test: 0.39440689433014053
# 71
# Mean value of R2 of training set 0.7964043197803972
# Mean value of R2 of test set 0.39423564875789596
# Standard deviation of R2 of test set 0.12319426920633202
# Train-Test: 0.4021686710225012
# 72
# Mean value of R2 of training set 0.7996967462044724
# Mean value of R2 of test set 0.3990839967464199
# Standard deviation of R2 of test set 0.1207846097775918
# Train-Test: 0.4006127494580525
# 73
# Mean value of R2 of training set 0.7940295702653586
# Mean value of R2 of test set 0.39625313906023973
# Standard deviation of R2 of test set 0.12317530884949061
# Train-Test: 0.39777643120511885
# 74
# Mean value of R2 of training set 0.79579820064164
# Mean value of R2 of test set 0.39443793742916794
# Standard deviation of R2 of test set 0.12002973358027086
# Train-Test: 0.40136026321247203
# 75
# Mean value of R2 of training set 0.7960924974504389
# Mean value of R2 of test set 0.3979222874703459
# Standard deviation of R2 of test set 0.12297915814844057
# Train-Test: 0.39817020998009295
# 76
# Mean value of R2 of training set 0.7975791863543245
# Mean value of R2 of test set 0.39756562587609345
# Standard deviation of R2 of test set 0.12196127040778999
# Train-Test: 0.400013560478231
# 77
# Mean value of R2 of training set 0.7969059882229352
# Mean value of R2 of test set 0.40091825177821705
# Standard deviation of R2 of test set 0.12276012431394726
# Train-Test: 0.3959877364447182
# 78
# Mean value of R2 of training set 0.7940744639067642
# Mean value of R2 of test set 0.3970219908625608
# Standard deviation of R2 of test set 0.12116201786553803
# Train-Test: 0.3970524730442034
# 79
# Mean value of R2 of training set 0.7952073086261688
# Mean value of R2 of test set 0.3989008053566465
# Standard deviation of R2 of test set 0.12404393256794108
# Train-Test: 0.3963065032695223
# 80
# Mean value of R2 of training set 0.7957240665154163
# Mean value of R2 of test set 0.39725606816970355
# Standard deviation of R2 of test set 0.12091491887225261
# Train-Test: 0.3984679983457127
# 81
# Mean value of R2 of training set 0.7941204265528141
# Mean value of R2 of test set 0.3977098848472448
# Standard deviation of R2 of test set 0.12088945026553954
# Train-Test: 0.39641054170556933
# 82
# Mean value of R2 of training set 0.7960042544568112
# Mean value of R2 of test set 0.39499016089106964
# Standard deviation of R2 of test set 0.1250674952426862
# Train-Test: 0.4010140935657416
# 83
# Mean value of R2 of training set 0.795298257770439
# Mean value of R2 of test set 0.40140553049832667
# Standard deviation of R2 of test set 0.12032503446448185
# Train-Test: 0.3938927272721124
# 84
# Mean value of R2 of training set 0.7964219091690796
# Mean value of R2 of test set 0.39826473877146834
# Standard deviation of R2 of test set 0.12129606495577117
# Train-Test: 0.3981571703976113
# 85
# Mean value of R2 of training set 0.795944891936725
# Mean value of R2 of test set 0.4017399693520207
# Standard deviation of R2 of test set 0.12152694043101642
# Train-Test: 0.3942049225847043
# 86
# Mean value of R2 of training set 0.7959621868741457
# Mean value of R2 of test set 0.39627496323565625
# Standard deviation of R2 of test set 0.12002925947728639
# Train-Test: 0.3996872236384894
# 87
# Mean value of R2 of training set 0.795375720611349
# Mean value of R2 of test set 0.39831779716938115
# Standard deviation of R2 of test set 0.12445168075785544
# Train-Test: 0.39705792344196783
# 88
# Mean value of R2 of training set 0.7965501077172309
# Mean value of R2 of test set 0.39977110787147846
# Standard deviation of R2 of test set 0.11971940680317654
# Train-Test: 0.39677899984575243
# 89
# Mean value of R2 of training set 0.7966011140541073
# Mean value of R2 of test set 0.39664651543744534
# Standard deviation of R2 of test set 0.12217756115796774
# Train-Test: 0.39995459861666194
# 90
# Mean value of R2 of training set 0.794730429416825
# Mean value of R2 of test set 0.3981466403859574
# Standard deviation of R2 of test set 0.12512370289282476
# Train-Test: 0.39658378903086766
# 91
# Mean value of R2 of training set 0.794468615120605
# Mean value of R2 of test set 0.39978504023612826
# Standard deviation of R2 of test set 0.12092239578966217
# Train-Test: 0.3946835748844767
# 92
# Mean value of R2 of training set 0.7958188312382033
# Mean value of R2 of test set 0.39599019210640984
# Standard deviation of R2 of test set 0.12160912937920303
# Train-Test: 0.39982863913179345
# 93
# Mean value of R2 of training set 0.7954749281198359
# Mean value of R2 of test set 0.39785726505525126
# Standard deviation of R2 of test set 0.12110848705495483
# Train-Test: 0.3976176630645846
# 94
# Mean value of R2 of training set 0.7969670748152324
# Mean value of R2 of test set 0.39874613614490634
# Standard deviation of R2 of test set 0.12163704636883112
# Train-Test: 0.3982209386703261
# 95
# Mean value of R2 of training set 0.7957871873956858
# Mean value of R2 of test set 0.3954571028650633
# Standard deviation of R2 of test set 0.11872473878178316
# Train-Test: 0.40033008453062247
# 96
# Mean value of R2 of training set 0.7954438278980461
# Mean value of R2 of test set 0.39850735443018226
# Standard deviation of R2 of test set 0.11919699989315055
# Train-Test: 0.39693647346786387
# 97
# Mean value of R2 of training set 0.7948460793928044
# Mean value of R2 of test set 0.397250844157644
# Standard deviation of R2 of test set 0.11924862872639429
# Train-Test: 0.3975952352351604
# 98
# Mean value of R2 of training set 0.7942173072433824
# Mean value of R2 of test set 0.3946441088756997
# Standard deviation of R2 of test set 0.12215225094590247
# Train-Test: 0.3995731983676827
# 99
# Mean value of R2 of training set 0.7922374827502133
# Mean value of R2 of test set 0.39380965104823906
# Standard deviation of R2 of test set 0.1232716913024829
# Train-Test: 0.39842783170197427
# 100
# Mean value of R2 of training set 0.794651403921045
# Mean value of R2 of test set 0.39725766337426466
# Standard deviation of R2 of test set 0.12437786983879899
# Train-Test: 0.3973937405467804
# 101
# Mean value of R2 of training set 0.7963054046438062
# Mean value of R2 of test set 0.3961217741892627
# Standard deviation of R2 of test set 0.12205186914614835
# Train-Test: 0.40018363045454347
# 102
# Mean value of R2 of training set 0.7964189771645644
# Mean value of R2 of test set 0.399016140538483
# Standard deviation of R2 of test set 0.12003775423957426
# Train-Test: 0.39740283662608145
# 103
# Mean value of R2 of training set 0.7959129345321071
# Mean value of R2 of test set 0.392986487498694
# Standard deviation of R2 of test set 0.12276615693009471
# Train-Test: 0.40292644703341307
# 104
# Mean value of R2 of training set 0.7955342042041273
# Mean value of R2 of test set 0.39898614992004255
# Standard deviation of R2 of test set 0.1191155059919355
# Train-Test: 0.3965480542840848
# 105
# Mean value of R2 of training set 0.796943231237111
# Mean value of R2 of test set 0.39766846042604487
# Standard deviation of R2 of test set 0.11986816681813028
# Train-Test: 0.3992747708110661
# 106
# Mean value of R2 of training set 0.7968243947567144
# Mean value of R2 of test set 0.39834807158283253
# Standard deviation of R2 of test set 0.12113981775143635
# Train-Test: 0.3984763231738819
# 107
# Mean value of R2 of training set 0.7966309267863178
# Mean value of R2 of test set 0.3974884173127744
# Standard deviation of R2 of test set 0.1206863148122486
# Train-Test: 0.39914250947354335
# 108
# Mean value of R2 of training set 0.7941077240010594
# Mean value of R2 of test set 0.39559737909854426
# Standard deviation of R2 of test set 0.12108935804335048
# Train-Test: 0.3985103449025152
# 109
# Mean value of R2 of training set 0.7946374458423113
# Mean value of R2 of test set 0.3967447029081811
# Standard deviation of R2 of test set 0.12293380167052781
# Train-Test: 0.39789274293413024
# 110
# Mean value of R2 of training set 0.7953565942500695
# Mean value of R2 of test set 0.39878563409883383
# Standard deviation of R2 of test set 0.12062421939532131
# Train-Test: 0.3965709601512357
# 111
# Mean value of R2 of training set 0.7936293213795846
# Mean value of R2 of test set 0.4007699964390659
# Standard deviation of R2 of test set 0.12118803408368144
# Train-Test: 0.39285932494051873
# 112
# Mean value of R2 of training set 0.795880636897178
# Mean value of R2 of test set 0.3991187091762699
# Standard deviation of R2 of test set 0.12092796243129852
# Train-Test: 0.3967619277209081
# 113
# Mean value of R2 of training set 0.7956430625729722
# Mean value of R2 of test set 0.3970634373247438
# Standard deviation of R2 of test set 0.12405717610409908
# Train-Test: 0.39857962524822843
# 114
# Mean value of R2 of training set 0.7923007648676361
# Mean value of R2 of test set 0.3955712139010884
# Standard deviation of R2 of test set 0.12323959704820314
# Train-Test: 0.3967295509665477
# 115
# Mean value of R2 of training set 0.7977728022964241
# Mean value of R2 of test set 0.3968119355915434
# Standard deviation of R2 of test set 0.12154676116796749
# Train-Test: 0.40096086670488074
# 116
# Mean value of R2 of training set 0.7954991392821829
# Mean value of R2 of test set 0.3990700304022413
# Standard deviation of R2 of test set 0.12236092948921481
# Train-Test: 0.39642910887994154
# 117
# Mean value of R2 of training set 0.7969369603732733
# Mean value of R2 of test set 0.3963857304225084
# Standard deviation of R2 of test set 0.12226965247138304
# Train-Test: 0.4005512299507649
# 118
# Mean value of R2 of training set 0.7972211902318774
# Mean value of R2 of test set 0.39746504597181037
# Standard deviation of R2 of test set 0.12410297390846502
# Train-Test: 0.39975614426006706
# 119
# Mean value of R2 of training set 0.7943246651582954
# Mean value of R2 of test set 0.39544426325312243
# Standard deviation of R2 of test set 0.1207084918300097
# Train-Test: 0.39888040190517293
# 120
# Mean value of R2 of training set 0.7967343682137336
# Mean value of R2 of test set 0.39762839679291084
# Standard deviation of R2 of test set 0.12234510387137798
# Train-Test: 0.3991059714208227
# 121
# Mean value of R2 of training set 0.7943003227576081
# Mean value of R2 of test set 0.39357190094724276
# Standard deviation of R2 of test set 0.12313173521567113
# Train-Test: 0.40072842181036533
# 122
# Mean value of R2 of training set 0.7959643103757668
# Mean value of R2 of test set 0.3997851504397458
# Standard deviation of R2 of test set 0.12513893316140282
# Train-Test: 0.396179159936021
# 123
# Mean value of R2 of training set 0.79461461473572
# Mean value of R2 of test set 0.3964816963622188
# Standard deviation of R2 of test set 0.11802609697062663
# Train-Test: 0.39813291837350123
# 124
# Mean value of R2 of training set 0.7956705391967864
# Mean value of R2 of test set 0.3977866155416729
# Standard deviation of R2 of test set 0.1243304554267847
# Train-Test: 0.39788392365511355
# 125
# Mean value of R2 of training set 0.7971534727826791
# Mean value of R2 of test set 0.3979311688496176
# Standard deviation of R2 of test set 0.12308192533695647
# Train-Test: 0.3992223039330615
# 126
# Mean value of R2 of training set 0.795072632749466
# Mean value of R2 of test set 0.39715424469061994
# Standard deviation of R2 of test set 0.12161230782406147
# Train-Test: 0.3979183880588461
# 127
# Mean value of R2 of training set 0.7952253995423074
# Mean value of R2 of test set 0.39572160907340853
# Standard deviation of R2 of test set 0.12192103454840408
# Train-Test: 0.3995037904688989
# 128
# Mean value of R2 of training set 0.7931356856109905
# Mean value of R2 of test set 0.39299173097403206
# Standard deviation of R2 of test set 0.12248250749559556
# Train-Test: 0.4001439546369584
# 129
# Mean value of R2 of training set 0.7964259793811549
# Mean value of R2 of test set 0.40001490915247834
# Standard deviation of R2 of test set 0.12174538753484895
# Train-Test: 0.39641107022867655
# 130
# Mean value of R2 of training set 0.7954131861263586
# Mean value of R2 of test set 0.39677115573455213
# Standard deviation of R2 of test set 0.1233098161832662
# Train-Test: 0.39864203039180646
# 131
# Mean value of R2 of training set 0.7942035183405425
# Mean value of R2 of test set 0.3959629565190977
# Standard deviation of R2 of test set 0.12308802718842972
# Train-Test: 0.3982405618214448
# 132
# Mean value of R2 of training set 0.796967006240592
# Mean value of R2 of test set 0.4046355227977102
# Standard deviation of R2 of test set 0.12180861350864094
# Train-Test: 0.3923314834428818
# 133
# Mean value of R2 of training set 0.7936610583134925
# Mean value of R2 of test set 0.39889087261490275
# Standard deviation of R2 of test set 0.12117072158473131
# Train-Test: 0.3947701856985898
# 134
# Mean value of R2 of training set 0.7949344242386175
# Mean value of R2 of test set 0.3936716892778107
# Standard deviation of R2 of test set 0.12048127119236098
# Train-Test: 0.4012627349608068
# 135
# Mean value of R2 of training set 0.7974487437579427
# Mean value of R2 of test set 0.3987937498151867
# Standard deviation of R2 of test set 0.11866629829553706
# Train-Test: 0.398654993942756
# 136
# Mean value of R2 of training set 0.7950435455523964
# Mean value of R2 of test set 0.398104609322681
# Standard deviation of R2 of test set 0.12014940941159957
# Train-Test: 0.39693893622971543
# 137
# Mean value of R2 of training set 0.7971529829231966
# Mean value of R2 of test set 0.3988585674467644
# Standard deviation of R2 of test set 0.12361325537375517
# Train-Test: 0.3982944154764322
# 138
# Mean value of R2 of training set 0.7952101621927955
# Mean value of R2 of test set 0.39528187615645927
# Standard deviation of R2 of test set 0.12411577762915345
# Train-Test: 0.39992828603633623
# 139
# Mean value of R2 of training set 0.7946159560061588
# Mean value of R2 of test set 0.3969614132568915
# Standard deviation of R2 of test set 0.12084944808161355
# Train-Test: 0.39765454274926726
# 140
# Mean value of R2 of training set 0.795802090413557
# Mean value of R2 of test set 0.3941497081407519
# Standard deviation of R2 of test set 0.12170358261425718
# Train-Test: 0.4016523822728051
# 141
# Mean value of R2 of training set 0.7964508376081803
# Mean value of R2 of test set 0.3967473417343047
# Standard deviation of R2 of test set 0.12459183203545968
# Train-Test: 0.39970349587387555
# 142
# Mean value of R2 of training set 0.7952140625729465
# Mean value of R2 of test set 0.3990837311588116
# Standard deviation of R2 of test set 0.12037131350697465
# Train-Test: 0.39613033141413484
# 143
# Mean value of R2 of training set 0.7954382109360464
# Mean value of R2 of test set 0.3962992022499594
# Standard deviation of R2 of test set 0.1229262553581432
# Train-Test: 0.399139008686087
# 144
# Mean value of R2 of training set 0.7969809125952879
# Mean value of R2 of test set 0.39920908662009474
# Standard deviation of R2 of test set 0.12072464092974736
# Train-Test: 0.39777182597519317
# 145
# Mean value of R2 of training set 0.7948508023665177
# Mean value of R2 of test set 0.3942770890102773
# Standard deviation of R2 of test set 0.1239744800748582
# Train-Test: 0.4005737133562404
# 146
# Mean value of R2 of training set 0.7942786794519918
# Mean value of R2 of test set 0.3915211581314686
# Standard deviation of R2 of test set 0.12010200147562862
# Train-Test: 0.4027575213205232
# 147
# Mean value of R2 of training set 0.796138198683181
# Mean value of R2 of test set 0.3939177175507993
# Standard deviation of R2 of test set 0.12120132567834944
# Train-Test: 0.40222048113238174
# 148
# Mean value of R2 of training set 0.7946915120056137
# Mean value of R2 of test set 0.39896738276204297
# Standard deviation of R2 of test set 0.12168831661808648
# Train-Test: 0.39572412924357075
# 149
# Mean value of R2 of training set 0.7953667842193454
# Mean value of R2 of test set 0.4019358695046135
# Standard deviation of R2 of test set 0.11641342124851221
# Train-Test: 0.39343091471473185
# 150
# Mean value of R2 of training set 0.7938353234132939
# Mean value of R2 of test set 0.39495325289075744
# Standard deviation of R2 of test set 0.12370802860938723
# Train-Test: 0.39888207052253644
# 151
# Mean value of R2 of training set 0.7945812037234823
# Mean value of R2 of test set 0.39723565305932856
# Standard deviation of R2 of test set 0.12212712970298047
# Train-Test: 0.3973455506641537
# 152
# Mean value of R2 of training set 0.7973045218890671
# Mean value of R2 of test set 0.39828121618303436
# Standard deviation of R2 of test set 0.11959763694309403
# Train-Test: 0.3990233057060327
# 153
# Mean value of R2 of training set 0.7962850532372291
# Mean value of R2 of test set 0.3983759073427784
# Standard deviation of R2 of test set 0.12033313641851717
# Train-Test: 0.3979091458944507
# 154
# Mean value of R2 of training set 0.7959312948015245
# Mean value of R2 of test set 0.396806606834509
# Standard deviation of R2 of test set 0.12056331834284434
# Train-Test: 0.39912468796701545
# 155
# Mean value of R2 of training set 0.7972156934780265
# Mean value of R2 of test set 0.39951959016377336
# Standard deviation of R2 of test set 0.11964815060283718
# Train-Test: 0.3976961033142531
# 156
# Mean value of R2 of training set 0.7945457911733109
# Mean value of R2 of test set 0.39382542040076324
# Standard deviation of R2 of test set 0.12560385352383147
# Train-Test: 0.4007203707725477
# 157
# Mean value of R2 of training set 0.7944892097971962
# Mean value of R2 of test set 0.39791159714409957
# Standard deviation of R2 of test set 0.12156048025445013
# Train-Test: 0.3965776126530966
# 158
# Mean value of R2 of training set 0.7944605685537394
# Mean value of R2 of test set 0.3954839379809365
# Standard deviation of R2 of test set 0.12093516718349528
# Train-Test: 0.39897663057280286
# 159
# Mean value of R2 of training set 0.7973478298098199
# Mean value of R2 of test set 0.3981305174540381
# Standard deviation of R2 of test set 0.12157432006606386
# Train-Test: 0.3992173123557818
# 160
# Mean value of R2 of training set 0.7951439078472915
# Mean value of R2 of test set 0.39571128250701976
# Standard deviation of R2 of test set 0.12037741367103019
# Train-Test: 0.39943262534027174
# 161
# Mean value of R2 of training set 0.7947950266651719
# Mean value of R2 of test set 0.39987011854293136
# Standard deviation of R2 of test set 0.12316946255062326
# Train-Test: 0.3949249081222405
# 162
# Mean value of R2 of training set 0.7958345358980534
# Mean value of R2 of test set 0.3990867790702343
# Standard deviation of R2 of test set 0.1231249906710203
# Train-Test: 0.3967477568278191
# 163
# Mean value of R2 of training set 0.7947545642722622
# Mean value of R2 of test set 0.39796458385114597
# Standard deviation of R2 of test set 0.12311716160331848
# Train-Test: 0.39678998042111624
# 164
# Mean value of R2 of training set 0.7952086095984718
# Mean value of R2 of test set 0.39421380114127175
# Standard deviation of R2 of test set 0.12118127610009849
# Train-Test: 0.4009948084572001
# 165
# Mean value of R2 of training set 0.7968793315769563
# Mean value of R2 of test set 0.3996455601814086
# Standard deviation of R2 of test set 0.12154502960256315
# Train-Test: 0.3972337713955477
# 166
# Mean value of R2 of training set 0.7937786706169956
# Mean value of R2 of test set 0.3958550957845248
# Standard deviation of R2 of test set 0.12342674828747484
# Train-Test: 0.39792357483247076
# 167
# Mean value of R2 of training set 0.7953381015859864
# Mean value of R2 of test set 0.4001540398867433
# Standard deviation of R2 of test set 0.12015523045196154
# Train-Test: 0.3951840616992431
# 168
# Mean value of R2 of training set 0.7938833493208803
# Mean value of R2 of test set 0.3951903725777943
# Standard deviation of R2 of test set 0.12642667978813474
# Train-Test: 0.398692976743086
# 169
# Mean value of R2 of training set 0.7950912102039254
# Mean value of R2 of test set 0.3994658548902737
# Standard deviation of R2 of test set 0.12221814297472847
# Train-Test: 0.39562535531365167
# 170
# Mean value of R2 of training set 0.7982363628303415
# Mean value of R2 of test set 0.3973985491222827
# Standard deviation of R2 of test set 0.12213828030923972
# Train-Test: 0.4008378137080588
# 171
# Mean value of R2 of training set 0.7968779284337235
# Mean value of R2 of test set 0.39691290886915376
# Standard deviation of R2 of test set 0.12187846207105224
# Train-Test: 0.39996501956456976
# 172
# Mean value of R2 of training set 0.7958823773747874
# Mean value of R2 of test set 0.3994370524475243
# Standard deviation of R2 of test set 0.12080289789864332
# Train-Test: 0.3964453249272631
# 173
# Mean value of R2 of training set 0.7943432072311022
# Mean value of R2 of test set 0.39449968981534467
# Standard deviation of R2 of test set 0.12361104470408309
# Train-Test: 0.3998435174157575
# 174
# Mean value of R2 of training set 0.7974744515797916
# Mean value of R2 of test set 0.3980880794935594
# Standard deviation of R2 of test set 0.12226687193910446
# Train-Test: 0.3993863720862322
# 175
# Mean value of R2 of training set 0.7960102976012883
# Mean value of R2 of test set 0.39751975945457446
# Standard deviation of R2 of test set 0.1205006680279134
# Train-Test: 0.3984905381467138
# 176
# Mean value of R2 of training set 0.7998625467715412
# Mean value of R2 of test set 0.4009150029638765
# Standard deviation of R2 of test set 0.12204132904464458
# Train-Test: 0.39894754380766473
# 177
# Mean value of R2 of training set 0.7955142930806619
# Mean value of R2 of test set 0.3982960582134441
# Standard deviation of R2 of test set 0.12000405698506328
# Train-Test: 0.3972182348672178
# 178
# Mean value of R2 of training set 0.7963335703763077
# Mean value of R2 of test set 0.39546806497155723
# Standard deviation of R2 of test set 0.1231437464399898
# Train-Test: 0.40086550540475047
# 179
# Mean value of R2 of training set 0.7970168481818061
# Mean value of R2 of test set 0.40043428266382475
# Standard deviation of R2 of test set 0.12009754929935261
# Train-Test: 0.3965825655179813
# 180
# Mean value of R2 of training set 0.7974168190009031
# Mean value of R2 of test set 0.4006978811248502
# Standard deviation of R2 of test set 0.1185804177512829
# Train-Test: 0.3967189378760529
# 181
# Mean value of R2 of training set 0.795590117846316
# Mean value of R2 of test set 0.40030912466325985
# Standard deviation of R2 of test set 0.12064114640617675
# Train-Test: 0.3952809931830561
# 182
# Mean value of R2 of training set 0.794491378248174
# Mean value of R2 of test set 0.3985489065365164
# Standard deviation of R2 of test set 0.12031821344544619
# Train-Test: 0.39594247171165753
# 183
# Mean value of R2 of training set 0.7920596783458741
# Mean value of R2 of test set 0.3943087929919875
# Standard deviation of R2 of test set 0.12231011649846864
# Train-Test: 0.3977508853538866
# 184
# Mean value of R2 of training set 0.7937627378208295
# Mean value of R2 of test set 0.3973237214914598
# Standard deviation of R2 of test set 0.12112653231512512
# Train-Test: 0.39643901632936973
# 185
# Mean value of R2 of training set 0.7956623383465203
# Mean value of R2 of test set 0.40033100799646903
# Standard deviation of R2 of test set 0.12121177807939845
# Train-Test: 0.3953313303500513
# 186
# Mean value of R2 of training set 0.7941246648896542
# Mean value of R2 of test set 0.3965249687679881
# Standard deviation of R2 of test set 0.11972366836856976
# Train-Test: 0.39759969612166607
# 187
# Mean value of R2 of training set 0.7968431366389089
# Mean value of R2 of test set 0.39523662116049635
# Standard deviation of R2 of test set 0.12224517669618544
# Train-Test: 0.4016065154784126
# 188
# Mean value of R2 of training set 0.7928465210935507
# Mean value of R2 of test set 0.3994222624706156
# Standard deviation of R2 of test set 0.12048884527727734
# Train-Test: 0.3934242586229351
# 189
# Mean value of R2 of training set 0.794705368264988
# Mean value of R2 of test set 0.39926124832780097
# Standard deviation of R2 of test set 0.1262251985595336
# Train-Test: 0.3954441199371871
# 190
# Mean value of R2 of training set 0.796242581926991
# Mean value of R2 of test set 0.3976773981947583
# Standard deviation of R2 of test set 0.12201307826303849
# Train-Test: 0.39856518373223276
# 191
# Mean value of R2 of training set 0.7947025484242519
# Mean value of R2 of test set 0.3971021411114505
# Standard deviation of R2 of test set 0.12157111165792868
# Train-Test: 0.39760040731280144
# 192
# Mean value of R2 of training set 0.7946962971875388
# Mean value of R2 of test set 0.39931698313854846
# Standard deviation of R2 of test set 0.12308357946396856
# Train-Test: 0.3953793140489903
# 193
# Mean value of R2 of training set 0.7934088819276732
# Mean value of R2 of test set 0.397413896300024
# Standard deviation of R2 of test set 0.11954487339444404
# Train-Test: 0.39599498562764923
# 194
# Mean value of R2 of training set 0.7964253065178832
# Mean value of R2 of test set 0.39896954083245073
# Standard deviation of R2 of test set 0.12204632448745714
# Train-Test: 0.3974557656854325
# 195
# Mean value of R2 of training set 0.7936731922292134
# Mean value of R2 of test set 0.39733885522567675
# Standard deviation of R2 of test set 0.12303300724862722
# Train-Test: 0.39633433700353665
# 196
# Mean value of R2 of training set 0.7962568534601131
# Mean value of R2 of test set 0.4002924756656436
# Standard deviation of R2 of test set 0.12337568485287911
# Train-Test: 0.3959643777944695
# 197
# Mean value of R2 of training set 0.7961634245127339
# Mean value of R2 of test set 0.3955563085887882
# Standard deviation of R2 of test set 0.11969205615660615
# Train-Test: 0.4006071159239457
# 198
# Mean value of R2 of training set 0.7959073423445407
# Mean value of R2 of test set 0.40242065270507815
# Standard deviation of R2 of test set 0.12098513462556441
# Train-Test: 0.3934866896394626
# 199
# Mean value of R2 of training set 0.7932231537478127
# Mean value of R2 of test set 0.391380802683451
# Standard deviation of R2 of test set 0.12374557646309078
# Train-Test: 0.4018423510643617
# 200
# Mean value of R2 of training set 0.7926066203490819
# Mean value of R2 of test set 0.39612788499545537
# Standard deviation of R2 of test set 0.12417286083821126
# Train-Test: 0.39647873535362654

# %%
# TODO: Import 'RandomForestRegressor'
from sklearn.ensemble import RandomForestRegressor

from sklearn.model_selection import train_test_split

# TODO Calculate the r2 score between 'y_true' and 'y_predict'
from math import sqrt
from sklearn import metrics

group2 = Original_Features.loc[:,'Group']

# TODO: Shuffle and split the data into training and testing subsets
Features, X_valid, Oil_HHV, y_valid = train_test_split(Original_Features, Original_Oil_HHV, test_size = 0.1, stratify=group2, random_state=62)

X_valid_new=X_valid.drop('Group', axis=1)

Features_new=Features.drop('Group', axis=1)

cnt = 1

MAE_train_all=[]
MAE_test_all=[]
y_train_rmse_all=[]
y_test_rmse_all=[]
r2_train_all=[]
r2_test_all=[]
MRE_train_all=[]
MRE_test_all=[]
y_test_list=[]
y_pred_list=[]

# split()  method generate indices to split data into training and test set.
for i in range(5000,6000,10):

  X_train, X_test, y_train, y_test = train_test_split(Features_new, Oil_HHV, shuffle=True, test_size = 0.2, random_state=i)
  
  params = {'n_estimators':190,'max_depth':12,'min_samples_leaf':1,'min_samples_split':4,'max_features':1,'random_state':132}

  model = RandomForestRegressor(**params)

  model.fit(X_train, y_train)
    
  y_train_predict = model.predict(X_train)
  y_test_predict = model.predict(X_test)

  MAE_train = metrics.mean_absolute_error(y_train, y_train_predict)
  MAE_test = metrics.mean_absolute_error(y_test, y_test_predict)
    
  y_train_rmse = sqrt(metrics.mean_squared_error(y_train, y_train_predict))
  y_test_rmse = sqrt(metrics.mean_squared_error(y_test, y_test_predict))
    
  r2_train = metrics.r2_score(y_train, y_train_predict)
  r2_test = metrics.r2_score(y_test, y_test_predict)

  MRE_train = performance_metric(y_train, y_train_predict)
  MRE_test = performance_metric(y_test, y_test_predict)

  cnt += 1
  MAE_train_all.append(MAE_train)
  MAE_test_all.append(MAE_test)
  y_train_rmse_all.append(y_train_rmse)
  y_test_rmse_all.append(y_test_rmse)
  r2_train_all.append(r2_train)
  r2_test_all.append(r2_test)
  MRE_train_all.append(MRE_train)
  MRE_test_all.append(MRE_test)
  y_test_list.append(y_test.values)
  y_pred_list.append(y_test_predict)

y_test_all=np.concatenate(y_test_list, axis=0)
y_pred_all=np.concatenate(y_pred_list, axis=0)

print("Mean value of MAE of training set", np.mean(MAE_train_all))
print("Standard deviation of MAE of training set", np.std(MAE_train_all))
print("Mean value of MAE of test set", np.mean(MAE_test_all))
print("Standard deviation of MAE of test set", np.std(MAE_test_all))
print("")
print("Mean value of RMSE of training set", np.mean(y_train_rmse_all))
print("Standard deviation of RMSE of training set", np.std(y_train_rmse_all))
print("Mean value of RMSE of test set", np.mean(y_test_rmse_all))
print("Standard deviation of RMSE of test set", np.std(y_test_rmse_all))
print("")
print("Mean value of R2 of training set", np.mean(r2_train_all))
print("Standard deviation of R2 of training set", np.std(r2_train_all))
print("Mean value of R2 of test set", np.mean(r2_test_all))
print("Standard deviation of R2 of test set", np.std(r2_test_all))
print("")
print("Mean value of MRE of training set", np.mean(MRE_train_all))
print("Standard deviation of MRE of training set", np.std(MRE_train_all))
print("Mean value of MRE of test set", np.mean(MRE_test_all))
print("Standard deviation of MRE of test set", np.std(MRE_test_all))

# print(len(np.concatenate(y_test_list, axis=0)))
# print(len(np.concatenate(y_pred_list, axis=0)))

print("")
# Predict validation set
model.fit(Features_new, Oil_HHV)

y_valid_predict = model.predict(X_valid_new)

MAE_valid = metrics.mean_absolute_error(y_valid, y_valid_predict)
y_valid_rmse = sqrt(metrics.mean_squared_error(y_valid, y_valid_predict))
r2_valid = metrics.r2_score(y_valid, y_valid_predict)
MRE_valid = performance_metric(y_valid, y_valid_predict)

print("Optimal model has MAE of valid set:", MAE_valid)
print("Optimal model has RMSE of valid set:", y_valid_rmse)
print("Optimal model has R2 score of valid set", r2_valid)
print("Optimal model has MRE of valid set:", MRE_valid)
# Out:
# Mean value of MAE of training set 5.391256173107715
# Standard deviation of MAE of training set 0.20289368048801618
# Mean value of MAE of test set 9.1023910199625
# Standard deviation of MAE of test set 1.1377960716037154
#
# Mean value of RMSE of training set 7.498647730103811
# Standard deviation of RMSE of training set 0.30851909958331936
# Mean value of RMSE of test set 12.69372578143592
# Standard deviation of RMSE of test set 1.9049782676990874
#
# Mean value of R2 of training set 0.7985513626162469
# Standard deviation of R2 of training set 0.014524027081287012
# Mean value of R2 of test set 0.39866825643630266
# Standard deviation of R2 of test set 0.12718138247601996
#
# Mean value of MRE of training set 0.08237266711372282
# Standard deviation of MRE of training set 0.0031771415603473996
# Mean value of MRE of test set 0.13925182273824707
# Standard deviation of MRE of test set 0.018842411487525915
#
# Optimal model has MAE of valid set: 9.85342698996028
# Optimal model has RMSE of valid set: 12.6236438270864
# Optimal model has R2 score of valid set 0.5886687575373397
# Optimal model has MRE of valid set: 0.15059300606372464

# %%
import matplotlib.pyplot as py
py.plot(y_test_all, y_pred_all, 'bo')
py.ylim(0, 100)
py.xlabel('y_true')
py.ylabel('y_pred')
py.title('y_pred vs. y_true')
# Out:
# Text(0.5, 1.0, 'y_pred vs. y_true')

# %%
Parity={'Predict Data':y_pred_all,'Test Data':y_test_all}
df = pd.DataFrame(Parity, columns= ['Predict Data', 'Test Data'])
df.to_csv (r'/content/export_dataframe_RFR_opt.csv', index = False, header=True)

# %%
import matplotlib.pyplot as py
py.plot(y_valid, y_valid_predict, 'bo')
py.ylim(0, 100)
py.xlabel('y_true')
py.ylabel('y_pred')
py.title('y_pred vs. y_true')
# Out:
# Text(0.5, 1.0, 'y_pred vs. y_true')

# %%
Parity={'Predict Data':y_valid_predict,'Test Data':y_valid}
df = pd.DataFrame(Parity, columns= ['Predict Data', 'Test Data'])
df.to_csv (r'/content/export_dataframe_test_set_RFR_opt.csv', index = False, header=True)

# %%
import matplotlib.pyplot as plt

Features = Original_Features.drop('Group', axis=1)

Features.columns = ['Dichloromethane','Toluene','Acetone','Tetrahydrofuran','Methanol','Hexane','Diethyl Ether','Chloroform','Ethyl Acetate','Lipid','Protein','Cellulose','Hemicellulose','Carbohydrate','Lignin','Ash']
feat_labels = Features.columns[0:]

# get importance
importances = model.feature_importances_
indices = np.argsort(importances)[::-1]

x_columns = Features.columns[0:]
x_columns_indices = []

# summarize feature importance
for f in range(X_train.shape[1]):
    print("%2d) %-*s %f" % (f + 1, 30, feat_labels[indices[f]], importances[indices[f]]))
    x_columns_indices.append(feat_labels[indices[f]])

# plot feature importance
fig = plt.figure(figsize=(15, 9))
plt.title("Variable Importances", fontsize=18)
plt.ylabel("Import level", fontsize=18, rotation=90)

for i in range(x_columns.shape[0]):
    plt.bar(i, importances[indices[i]], color='green', align='center')
    plt.xticks(np.arange(x_columns.shape[0]), x_columns_indices, rotation=45, fontsize=18)
plt.show()

fig.savefig('Biocrude Yield RF Variable Importances.png')
# Out:
#  1) Lipid                          0.164585
#  2) Protein                        0.137782
#  3) Lignin                         0.129505
#  4) Ash                            0.125658
#  5) Cellulose                      0.123468
#  6) Carbohydrate                   0.103360
#  7) Hemicellulose                  0.092471
#  8) Toluene                        0.032332
#  9) Dichloromethane                0.029596
# 10) Hexane                         0.020546
# 11) Acetone                        0.019466
# 12) Tetrahydrofuran                0.011071
# 13) Methanol                       0.004860
# 14) Diethyl Ether                  0.002849
# 15) Ethyl Acetate                  0.001388
# 16) Chloroform                     0.001063
